# %% [markdown]
# https://realpython.com/python-scope-legb-rule/

# %% [markdown]
# The concept of scope rules determines the visibility of a variable within the code.
#
# The scope of a name or variable depends on the place in your code where you create that variable.

# %% [markdown]
# In programming, the scope of a **name** defines the area of a program in which you can unambiguously access that name, such as **variables, functions, objects, and so on**.

# %% [markdown]
# Global scope: The names that you define in this scope are available to all your code.
#
# Local scope: The names that you define in this scope are only available or visible to the code within the scope.

# %% [markdown]
# To work with global names, you’d need to keep all the code in mind at the same time to know what the value of a given name is at any time. This was an important side-effect of not having scopes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# All these operations create or, in the case of assignments, update new Python names because all of them assign a name to a variable, constant, function, class, instance, module, or other Python object.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def square(base):
    result = base ** 2
    print(f'The square of {base} is: {result}')

square(10)
# Out:
# The square of 10 is: 100

# %%
result  # Isn't accessible from outside square()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-55cf1b8d4f03> in <module>
# ----> 1 result  # Isn't accessible from outside square()
#
# NameError: name 'result' is not defined

# %%
base  # Isn't accessible from outside square()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e17589c0c70c> in <module>
# ----> 1 base  # Isn't accessible from outside square()
#
# NameError: name 'base' is not defined

# %%
square(20)
# Out:
# The square of 20 is: 400

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def outer_func():
    # This block is the Local scope of outer_func()
    var = 100  # A nonlocal var
    # It's also the enclosing scope of inner_func()
    def inner_func():
        # This block is the Local scope of inner_func()
        print(f"Printing var from inner_func(): {var}")

    inner_func()
    print(f"Printing var from outer_func(): {var}")

outer_func()
inner_func()
# Out:
# Printing var from inner_func(): 100
# Printing var from outer_func(): 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3dfa967da06c> in <module>
#      13
#      14
# ---> 15 inner_func()
#
# NameError: name 'inner_func' is not defined

# %%
def outer_func():
    var = 100
    def inner_func():
        print(f"Printing var from inner_func(): {var}")
        print(f"Printing another_var from inner_func(): {another_var}")

    inner_func()
    another_var = 200  # This is defined after calling inner_func()
    print(f"Printing var from outer_func(): {var}")

outer_func()
# Out:
# Printing var from inner_func(): 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b88ddc966bd> in <module>
#       9     print(f"Printing var from outer_func(): {var}")
#      10
# ---> 11 outer_func()
#
# <ipython-input-7-2b88ddc966bd> in outer_func()
#       5         print(f"Printing another_var from inner_func(): {another_var}")
#       6
# ----> 7     inner_func()
#       8     another_var = 200  # This is defined after calling inner_func()
#       9     print(f"Printing var from outer_func(): {var}")
#
# <ipython-input-7-2b88ddc966bd> in inner_func()
#       3     def inner_func():
#       4         print(f"Printing var from inner_func(): {var}")
# ----> 5         print(f"Printing another_var from inner_func(): {another_var}")
#       6
#       7     inner_func()
#
# NameError: free variable 'another_var' referenced before assignment in enclosing scope

# %%
def outer_func():
    var = 100
    another_var = 200  # This is defined before calling inner_func()

    def inner_func():
        print(f"Printing var from inner_func(): {var}")
        print(f"Printing another_var from inner_func(): {another_var}")

    inner_func()
    print(f"Printing var from outer_func(): {var}")

outer_func()
# Out:
# Printing var from inner_func(): 100
# Printing another_var from inner_func(): 200
# Printing var from outer_func(): 100

# %%
var = 100
def func():
    return var  # You can access var from inside func()

func()
# Out:
# 100

# %%
var  # Remains unchanged
# Out:
# 100

# %%
var = 100  # A global variable

def increment():
    var = var + 1  # Try to update a global variable

increment()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-15-7d048fd17cd1> in <module>
#       4     var = var + 1  # Try to update a global variable
#       5
# ----> 6 increment()
#
# <ipython-input-15-7d048fd17cd1> in increment()
#       2
#       3 def increment():
# ----> 4     var = var + 1  # Try to update a global variable
#       5
#       6 increment()
#
# UnboundLocalError: local variable 'var' referenced before assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var = 100  # A global variable
def func():
    print(var)  # Reference the global variable, var
    var = 200   # Define a new local variable using the same name, var

func()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-16-9b176fbace62> in <module>
#       4     var = 200   # Define a new local variable using the same name, var
#       5
# ----> 6 func()
#
# <ipython-input-16-9b176fbace62> in func()
#       1 var = 100  # A global variable
#       2 def func():
# ----> 3     print(var)  # Reference the global variable, var
#       4     var = 200   # Define a new local variable using the same name, var
#       5
#
# UnboundLocalError: local variable 'var' referenced before assignment

# %% [markdown]
# The **global** Statement

# %%
counter = 0  # A global name
def update_counter():
    counter = counter + 1  # Fail trying to update counter

update_counter()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-17-d9a8f973a26e> in <module>
#       3     counter = counter + 1  # Fail trying to update counter
#       4
# ----> 5 update_counter()
#
# <ipython-input-17-d9a8f973a26e> in update_counter()
#       1 counter = 0  # A global name
#       2 def update_counter():
# ----> 3     counter = counter + 1  # Fail trying to update counter
#       4
#       5 update_counter()
#
# UnboundLocalError: local variable 'counter' referenced before assignment

# %%
counter = 0  # A global name
def update_counter():
    global counter  # Declare counter as global
    counter = counter + 1  # Successfully update the counter

update_counter()
print(counter)

update_counter()
print(counter)

update_counter()
print(counter)
# Out:
# 1
# 2
# 3

# %%
def create_lazy_name():
    global lazy  # Create a global name, lazy
    lazy = 100
    return lazy

create_lazy_name()
# Out:
# 100

# %%
lazy  # The name is now available in the global scope
# Out:
# 100
